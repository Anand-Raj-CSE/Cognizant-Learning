# %%
import pandas as pd

# %%
bond = pd.read_csv("jamesbond.csv")
bond.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %% [markdown]
# # Setting up and resetting up the index

# %%
bond.set_index("Film")
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
bond.reset_index(inplace=True)
bond.set_index("Film",inplace=True)
bond.head()
# Out:
#                        index  Year         Actor       Director  Box Office  \
# Film
# Dr. No                     0  1962  Sean Connery  Terence Young       448.8
# From Russia with Love      1  1963  Sean Connery  Terence Young       543.8
# Goldfinger                 2  1964  Sean Connery   Guy Hamilton       820.4
# Thunderball                3  1965  Sean Connery  Terence Young       848.1
# Casino Royale              4  1967   David Niven     Ken Hughes       315.0
#
#                        Budget  Bond Actor Salary
# Film
# Dr. No                    7.0                0.6
# From Russia with Love    12.6                1.6
# Goldfinger               18.6                3.2
# Thunderball              41.9                4.7
# Casino Royale            85.0                NaN

# %%
bond.reset_index(inplace=True)
bond.set_index("Year",inplace=True)
bond.head()
# Out:
#                        Film  index         Actor       Director  Box Office  \
# Year
# 1962                 Dr. No      0  Sean Connery  Terence Young       448.8
# 1963  From Russia with Love      1  Sean Connery  Terence Young       543.8
# 1964             Goldfinger      2  Sean Connery   Guy Hamilton       820.4
# 1965            Thunderball      3  Sean Connery  Terence Young       848.1
# 1967          Casino Royale      4   David Niven     Ken Hughes       315.0
#
#       Budget  Bond Actor Salary
# Year
# 1962     7.0                0.6
# 1963    12.6                1.6
# 1964    18.6                3.2
# 1965    41.9                4.7
# 1967    85.0                NaN

# %%
bond.reset_index(inplace=True)

# %%
bond.head()
# Out:
#    Year                   Film  index         Actor       Director  \
# 0  1962                 Dr. No      0  Sean Connery  Terence Young
# 1  1963  From Russia with Love      1  Sean Connery  Terence Young
# 2  1964             Goldfinger      2  Sean Connery   Guy Hamilton
# 3  1965            Thunderball      3  Sean Connery  Terence Young
# 4  1967          Casino Royale      4   David Niven     Ken Hughes
#
#    Box Office  Budget  Bond Actor Salary
# 0       448.8     7.0                0.6
# 1       543.8    12.6                1.6
# 2       820.4    18.6                3.2
# 3       848.1    41.9                4.7
# 4       315.0    85.0                NaN

# %%
bond.set_index("Film",inplace=True)
bond.head()
# Out:
#                        Year  index         Actor       Director  Box Office  \
# Film
# Dr. No                 1962      0  Sean Connery  Terence Young       448.8
# From Russia with Love  1963      1  Sean Connery  Terence Young       543.8
# Goldfinger             1964      2  Sean Connery   Guy Hamilton       820.4
# Thunderball            1965      3  Sean Connery  Terence Young       848.1
# Casino Royale          1967      4   David Niven     Ken Hughes       315.0
#
#                        Budget  Bond Actor Salary
# Film
# Dr. No                    7.0                0.6
# From Russia with Love    12.6                1.6
# Goldfinger               18.6                3.2
# Thunderball              41.9                4.7
# Casino Royale            85.0                NaN

# %%
# Always set the column which needs to be located
bond.loc["Goldfinger"]
# Out:
# Year                         1964
# index                           2
# Actor                Sean Connery
# Director             Guy Hamilton
# Box Office                  820.4
# Budget                       18.6
# Bond Actor Salary             3.2
# Name: Goldfinger, dtype: object

# %%
# We can do all the slcing operations
bond.loc["Dr. No": : 2]
# Out:
#                                  Year  index           Actor         Director  \
# Film
# Dr. No                           1962      0    Sean Connery    Terence Young
# Goldfinger                       1964      2    Sean Connery     Guy Hamilton
# Casino Royale                    1967      4     David Niven       Ken Hughes
# On Her Majesty's Secret Service  1969      6  George Lazenby    Peter R. Hunt
# Live and Let Die                 1973      8     Roger Moore     Guy Hamilton
# The Spy Who Loved Me             1977     10     Roger Moore    Lewis Gilbert
# For Your Eyes Only               1981     12     Roger Moore        John Glen
# Octopussy                        1983     14     Roger Moore        John Glen
# The Living Daylights             1987     16  Timothy Dalton        John Glen
# GoldenEye                        1995     18  Pierce Brosnan  Martin Campbell
# The World Is Not Enough          1999     20  Pierce Brosnan    Michael Apted
# ...

# %%
bond.loc[["Goldfinger","Skyfall"]]
# Out:
#             Year  index         Actor      Director  Box Office  Budget  \
# Film
# Goldfinger  1964      2  Sean Connery  Guy Hamilton       820.4    18.6
# Skyfall     2012     24  Daniel Craig    Sam Mendes       943.5   170.2
#
#             Bond Actor Salary
# Film
# Goldfinger                3.2
# Skyfall                  14.5

# %%
bond.iloc[2:8]
# Out:
#                                  Year  index           Actor       Director  \
# Film
# Goldfinger                       1964      2    Sean Connery   Guy Hamilton
# Thunderball                      1965      3    Sean Connery  Terence Young
# Casino Royale                    1967      4     David Niven     Ken Hughes
# You Only Live Twice              1967      5    Sean Connery  Lewis Gilbert
# On Her Majesty's Secret Service  1969      6  George Lazenby  Peter R. Hunt
# Diamonds Are Forever             1971      7    Sean Connery   Guy Hamilton
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Goldfinger                            820.4    18.6                3.2
# Thunderball                           848.1    41.9                4.7
# Casino Royale                         315.0    85.0                NaN
# You Only Live Twice                   514.2    59.9                4.4
# ...

# %%
# Changing values of a row
bond.loc["Dr. No",["Box Office","Budget","Bond Actor Salary"]] = [448000000,7000000,600000]

# %%
bond.loc["Dr. No"]
# Out:
# Year                          1962
# index                            0
# Actor                 Sean Connery
# Director             Terence Young
# Box Office             448000000.0
# Budget                   7000000.0
# Bond Actor Salary         600000.0
# Name: Dr. No, dtype: object

# %% [markdown]
# # Deleting rows and columns from dataframe

# %%
bond.drop(["Casino Royale"])
# Out:
#                                  Year  index           Actor  \
# Film
# Dr. No                           1962      0    Sean Connery
# From Russia with Love            1963      1    Sean Connery
# Goldfinger                       1964      2    Sean Connery
# Thunderball                      1965      3    Sean Connery
# You Only Live Twice              1967      5    Sean Connery
# On Her Majesty's Secret Service  1969      6  George Lazenby
# Diamonds Are Forever             1971      7    Sean Connery
# Live and Let Die                 1973      8     Roger Moore
# The Man with the Golden Gun      1974      9     Roger Moore
# The Spy Who Loved Me             1977     10     Roger Moore
# Moonraker                        1979     11     Roger Moore
# For Your Eyes Only               1981     12     Roger Moore
# Never Say Never Again            1983     13    Sean Connery
# Octopussy                        1983     14     Roger Moore
# ...

# %%
# Removing certain columns
bond.drop(labels=["Box Office","Bond Actor Salary","Actor"], axis = "columns", inplace=True)

# %%
bond
# Out:
#                                  Year  index            Director     Budget
# Film
# Dr. No                           1962      0       Terence Young  7000000.0
# From Russia with Love            1963      1       Terence Young       12.6
# Goldfinger                       1964      2        Guy Hamilton       18.6
# Thunderball                      1965      3       Terence Young       41.9
# Casino Royale                    1967      4          Ken Hughes       85.0
# You Only Live Twice              1967      5       Lewis Gilbert       59.9
# On Her Majesty's Secret Service  1969      6       Peter R. Hunt       37.3
# Diamonds Are Forever             1971      7        Guy Hamilton       34.7
# Live and Let Die                 1973      8        Guy Hamilton       30.8
# The Man with the Golden Gun      1974      9        Guy Hamilton       27.7
# The Spy Who Loved Me             1977     10       Lewis Gilbert       45.1
# ...

# %%
bond = pd.read_csv("jamesbond.csv")
bond.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
actor = bond.pop("Actor") # pop removes and returns the column
print(actor)
# Out:
# 0       Sean Connery
# 1       Sean Connery
# 2       Sean Connery
# 3       Sean Connery
# 4        David Niven
# 5       Sean Connery
# 6     George Lazenby
# 7       Sean Connery
# 8        Roger Moore
# 9        Roger Moore
# 10       Roger Moore
# 11       Roger Moore
# 12       Roger Moore
# 13      Sean Connery
# 14       Roger Moore
# 15       Roger Moore
# 16    Timothy Dalton
# 17    Timothy Dalton
# 18    Pierce Brosnan
# 19    Pierce Brosnan
# 20    Pierce Brosnan
# 21    Pierce Brosnan
# 22      Daniel Craig
# 23      Daniel Craig
# 24      Daniel Craig
# 25      Daniel Craig
# Name: Actor, dtype: object

# %%
del bond["Director"]
bond
# Out:
#                                Film  Year  Box Office  Budget  \
# 0                            Dr. No  1962       448.8     7.0
# 1             From Russia with Love  1963       543.8    12.6
# 2                        Goldfinger  1964       820.4    18.6
# 3                       Thunderball  1965       848.1    41.9
# 4                     Casino Royale  1967       315.0    85.0
# 5               You Only Live Twice  1967       514.2    59.9
# 6   On Her Majesty's Secret Service  1969       291.5    37.3
# 7              Diamonds Are Forever  1971       442.5    34.7
# 8                  Live and Let Die  1973       460.3    30.8
# 9       The Man with the Golden Gun  1974       334.0    27.7
# 10             The Spy Who Loved Me  1977       533.0    45.1
# 11                        Moonraker  1979       535.0    91.5
# 12               For Your Eyes Only  1981       449.4    60.2
# 13            Never Say Never Again  1983       380.0    86.0
# ...

# %%
bond = pd.read_csv("jamesbond.csv")
bond.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
# Taking out Sample
bond.sample(n=5)
# Out:
#                                Film  Year           Actor       Director  \
# 15                 A View to a Kill  1985     Roger Moore      John Glen
# 0                            Dr. No  1962    Sean Connery  Terence Young
# 6   On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# 11                        Moonraker  1979     Roger Moore  Lewis Gilbert
# 17                  Licence to Kill  1989  Timothy Dalton      John Glen
#
#     Box Office  Budget  Bond Actor Salary
# 15       275.2    54.5                9.1
# 0        448.8     7.0                0.6
# 6        291.5    37.3                0.6
# 11       535.0    91.5                NaN
# 17       250.9    56.7                7.9

# %%
bond.sample(frac = 0.25)
# Out:
#                                Film  Year           Actor            Director  \
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 12               For Your Eyes Only  1981     Roger Moore           John Glen
# 19              Tomorrow Never Dies  1997  Pierce Brosnan  Roger Spottiswoode
# 18                        GoldenEye  1995  Pierce Brosnan     Martin Campbell
# 23                Quantum of Solace  2008    Daniel Craig        Marc Forster
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
#
#     Box Office  Budget  Bond Actor Salary
# 6        291.5    37.3                0.6
# 12       449.4    60.2                NaN
# 19       463.2   133.9               10.0
# 18       518.5    76.9                5.1
# 23       514.2   181.4                8.1
# 10       533.0    45.1                NaN

# %%
# Extracting random columns instead of rows
bond.sample(n=3,axis=1)
# Out:
#     Year            Director           Actor
# 0   1962       Terence Young    Sean Connery
# 1   1963       Terence Young    Sean Connery
# 2   1964        Guy Hamilton    Sean Connery
# 3   1965       Terence Young    Sean Connery
# 4   1967          Ken Hughes     David Niven
# 5   1967       Lewis Gilbert    Sean Connery
# 6   1969       Peter R. Hunt  George Lazenby
# 7   1971        Guy Hamilton    Sean Connery
# 8   1973        Guy Hamilton     Roger Moore
# 9   1974        Guy Hamilton     Roger Moore
# 10  1977       Lewis Gilbert     Roger Moore
# 11  1979       Lewis Gilbert     Roger Moore
# 12  1981           John Glen     Roger Moore
# 13  1983      Irvin Kershner    Sean Connery
# 14  1983           John Glen     Roger Moore
# 15  1985           John Glen     Roger Moore
# 16  1987           John Glen  Timothy Dalton
# 17  1989           John Glen  Timothy Dalton
# 18  1995     Martin Campbell  Pierce Brosnan
# 19  1997  Roger Spottiswoode  Pierce Brosnan
# ...

# %%
bond.nlargest(3,columns="Box Office")
# Out:
#            Film  Year         Actor       Director  Box Office  Budget  \
# 24      Skyfall  2012  Daniel Craig     Sam Mendes       943.5   170.2
# 3   Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
# 2    Goldfinger  1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#     Bond Actor Salary
# 24               14.5
# 3                 4.7
# 2                 3.2

# %%
bond.nsmallest(2,columns="Budget")
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6

# %%
bond.where(bond["Actor"] == "Daniel Craig")
# Out:
#                  Film    Year         Actor         Director  Box Office  \
# 0                 NaN     NaN           NaN              NaN         NaN
# 1                 NaN     NaN           NaN              NaN         NaN
# 2                 NaN     NaN           NaN              NaN         NaN
# 3                 NaN     NaN           NaN              NaN         NaN
# 4                 NaN     NaN           NaN              NaN         NaN
# 5                 NaN     NaN           NaN              NaN         NaN
# 6                 NaN     NaN           NaN              NaN         NaN
# 7                 NaN     NaN           NaN              NaN         NaN
# 8                 NaN     NaN           NaN              NaN         NaN
# 9                 NaN     NaN           NaN              NaN         NaN
# 10                NaN     NaN           NaN              NaN         NaN
# 11                NaN     NaN           NaN              NaN         NaN
# ...

# %%
bond.columns = [columns_name.replace(" ","_") for columns_name in bond.columns]
bond.head()
# Out:
#                     Film  Year         Actor       Director  Box_Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond_Actor_Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
print(bond.query("Actor == 'Daniel Craig'"))
bond.query('Actor == "Daniel Craig"')
# Out:
#                  Film  Year         Actor         Director  Box_Office  \
# 22      Casino Royale  2006  Daniel Craig  Martin Campbell       581.5
# 23  Quantum of Solace  2008  Daniel Craig     Marc Forster       514.2
# 24            Skyfall  2012  Daniel Craig       Sam Mendes       943.5
# 25            Spectre  2015  Daniel Craig       Sam Mendes       726.7
#
#     Budget  Bond_Actor_Salary
# 22   145.3                3.3
# 23   181.4                8.1
# 24   170.2               14.5
# 25   206.3                NaN
#                  Film  Year         Actor         Director  Box_Office  \
# 22      Casino Royale  2006  Daniel Craig  Martin Campbell       581.5
# 23  Quantum of Solace  2008  Daniel Craig     Marc Forster       514.2
# 24            Skyfall  2012  Daniel Craig       Sam Mendes       943.5
# 25            Spectre  2015  Daniel Craig       Sam Mendes       726.7
#
#     Budget  Bond_Actor_Salary
# 22   145.3                3.3
# 23   181.4                8.1
# ...

# %% [markdown]
# # Apply method takes a function and appplies the function to all the dataframe

# %%
def convert_to_million(number):
    return str(number) + " Millions"

bond["Box_Office"] = bond["Box_Office"].apply(convert_to_million)

# %%
bond.head()
# Out:
#                     Film  Year         Actor       Director      Box_Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young  448.8 Millions
# 1  From Russia with Love  1963  Sean Connery  Terence Young  543.8 Millions
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton  820.4 Millions
# 3            Thunderball  1965  Sean Connery  Terence Young  848.1 Millions
# 4          Casino Royale  1967   David Niven     Ken Hughes  315.0 Millions
#
#    Budget  Bond_Actor_Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %% [markdown]
# # Copying the dataframe to another dataframe

# %%
directors = bond["Director"].copy()

# %%
directors.head()
# Out:
# 0    Terence Young
# 1    Terence Young
# 2     Guy Hamilton
# 3    Terence Young
# 4       Ken Hughes
# Name: Director, dtype: object
